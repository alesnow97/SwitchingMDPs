# %%
import numpy as np

import utils
from Z_oldies.switchingBanditEnv_aistats import SwitchingBanditEnvAistats

# %%
num_states = 5
num_actions = 18
num_obs = 5
delta = 0.1

observation_multiplier = 20
# transition_multiplier = 15
transition_multiplier = 20
num_experiments = 5

# %%
switching = SwitchingBanditEnvAistats(num_states=num_states,
                               num_actions=num_actions,
                               num_obs=num_obs,
                               transition_multiplier=transition_multiplier,
                               observation_multiplier=observation_multiplier)
real_transition_matrix = switching.transition_matrix
# Out:
# Sigma min is 0.016640626588496615
# Sigma min is 0.023266296349655154
# Sigma min is 0.007411360856284326
# Sigma min is 0.0019050818565488363
# Sigma min is 0.018565188052727524
# Sigma min is 0.01789225054494508
# Sigma min is 0.010879306389544386
# Sigma min is 0.0019815184695807426
# Sigma min is 0.003606878820652603
# Sigma min is 0.2694655521147165
# Sigma min is 0.015211470980552212
# Sigma min is 0.004700103414270108
# Sigma min is 0.001846401474031653
# Sigma min is 0.0037979858183199494
# Sigma min is 0.21780142154682153
# Sigma min is 0.008516351862318304
# Sigma min is 0.01967811454280854
# Sigma min is 0.002393200963057624
# (5, 5)
# Kronecker sigma min is 0.0002769104532577714
# Product sigma min is 0.0002769104532577805
# (5, 5)
# Kronecker sigma min is 0.0003871657496519124
# Product sigma min is 0.00038716574965191327
# (5, 5)
# Kronecker sigma min is 0.0001233296885220269
# Product sigma min is 0.000123329688522028
# (5, 5)
# Kronecker sigma min is 3.170175579535299e-05
# Product sigma min is 3.1701755795349056e-05
# (5, 5)
# Kronecker sigma min is 0.0003089363619306657
# Product sigma min is 0.0003089363619306573
# (5, 5)
# Kronecker sigma min is 0.0002977382601462558
# Product sigma min is 0.00029773826014625613
# (5, 5)
# Kronecker sigma min is 0.00018103847517024677
# Product sigma min is 0.00018103847517025342
# (5, 5)
# Kronecker sigma min is 3.297370893050273e-05
# Product sigma min is 3.297370893050243e-05
# (5, 5)
# Kronecker sigma min is 6.002072360444517e-05
# Product sigma min is 6.002072360443702e-05
# (5, 5)
# Kronecker sigma min is 0.00448407563120408
# Product sigma min is 0.004484075631204071
# (5, 5)
# Kronecker sigma min is 0.0002531284084491229
# Product sigma min is 0.0002531284084491218
# (5, 5)
# Kronecker sigma min is 7.821266584418758e-05
# Product sigma min is 7.821266584418689e-05
# (5, 5)
# Kronecker sigma min is 3.072527746182071e-05
# Product sigma min is 3.0725277461810466e-05
# (5, 5)
# Kronecker sigma min is 6.320086379108288e-05
# Product sigma min is 6.320086379106803e-05
# (5, 5)
# Kronecker sigma min is 0.0036243521264043917
# Product sigma min is 0.0036243521264043978
# (5, 5)
# Kronecker sigma min is 0.0001417174312370939
# Product sigma min is 0.00014171743123708662
# (5, 5)
# Kronecker sigma min is 0.00032745615607254747
# Product sigma min is 0.0003274561560725417
# (5, 5)
# Kronecker sigma min is 3.9824363577468476e-05
# Product sigma min is 3.98243635774724e-05
# (5, 5)
# Kronecker sigma min is 0.000387165749651915
# Product sigma min is 0.00038716574965191327
# (5, 5)
# Kronecker sigma min is 0.000541320545829986
# Product sigma min is 0.0005413205458299768
# (5, 5)
# Kronecker sigma min is 0.00017243491803654247
# Product sigma min is 0.00017243491803654512
# (5, 5)
# Kronecker sigma min is 4.432419904481401e-05
# Product sigma min is 4.4324199044816454e-05
# (5, 5)
# Kronecker sigma min is 0.00043194316702183886
# Product sigma min is 0.0004319431670218359
# (5, 5)
# Kronecker sigma min is 0.00041628640354097075
# Product sigma min is 0.0004162864035409712
# (5, 5)
# Kronecker sigma min is 0.0002531211665378366
# Product sigma min is 0.00025312116653783656
# (5, 5)
# Kronecker sigma min is 4.6102595935582525e-05
# Product sigma min is 4.61025959355807e-05
# (5, 5)
# Kronecker sigma min is 8.39187115385985e-05
# Product sigma min is 8.391871153859815e-05
# (5, 5)
# Kronecker sigma min is 0.00626946539152446
# Product sigma min is 0.00626946539152444
# (5, 5)
# Kronecker sigma min is 0.0003539145917477069
# Product sigma min is 0.00035391459174770724
# (5, 5)
# Kronecker sigma min is 0.00010935399891041705
# Product sigma min is 0.00010935399891043436
# (5, 5)
# Kronecker sigma min is 4.2958923875257694e-05
# Product sigma min is 4.2958923875260546e-05
# (5, 5)
# Kronecker sigma min is 8.836506358081978e-05
# Product sigma min is 8.836506358081948e-05
# (5, 5)
# Kronecker sigma min is 0.005067432419084568
# Product sigma min is 0.005067432419084517
# (5, 5)
# Kronecker sigma min is 0.00019814396624663358
# Product sigma min is 0.00019814396624663524
# (5, 5)
# Kronecker sigma min is 0.0004578368445554444
# Product sigma min is 0.0004578368445554424
# (5, 5)
# Kronecker sigma min is 5.568092283077413e-05
# Product sigma min is 5.5680922830778796e-05
# (5, 5)
# Kronecker sigma min is 0.0001233296885220284
# Product sigma min is 0.000123329688522028
# (5, 5)
# Kronecker sigma min is 0.00017243491803654783
# Product sigma min is 0.00017243491803654512
# (5, 5)
# Kronecker sigma min is 5.4928269742077375e-05
# Product sigma min is 5.492826974206354e-05
# (5, 5)
# Kronecker sigma min is 1.4119249099644508e-05
# Product sigma min is 1.4119249099643517e-05
# (5, 5)
# Kronecker sigma min is 0.000137593308023553
# Product sigma min is 0.0001375933080235422
# (5, 5)
# Kronecker sigma min is 0.00013260592531963802
# Product sigma min is 0.00013260592531963788
# (5, 5)
# Kronecker sigma min is 8.063046551899325e-05
# Product sigma min is 8.063046551899322e-05
# (5, 5)
# Kronecker sigma min is 1.4685748421455426e-05
# Product sigma min is 1.468574842145514e-05
# (5, 5)
# Kronecker sigma min is 2.6731880504739262e-05
# Product sigma min is 2.6731880504745676e-05
# (5, 5)
# Kronecker sigma min is 0.001997106445060115
# Product sigma min is 0.001997106445060054
# (5, 5)
# Kronecker sigma min is 0.00011273770059177099
# Product sigma min is 0.00011273770059176962
# (5, 5)
# Kronecker sigma min is 3.483416246503154e-05
# Product sigma min is 3.4834162465009794e-05
# (5, 5)
# Kronecker sigma min is 1.3684347609626489e-05
# Product sigma min is 1.3684347609623873e-05
# (5, 5)
# Kronecker sigma min is 2.8148243426616374e-05
# Product sigma min is 2.8148243426619467e-05
# (5, 5)
# Kronecker sigma min is 0.0016142049300952458
# Product sigma min is 0.0016142049300951946
# (5, 5)
# Kronecker sigma min is 6.31177568307296e-05
# Product sigma min is 6.311775683073e-05
# (5, 5)
# Kronecker sigma min is 0.0001458416078480509
# Product sigma min is 0.00014584160784805055
# (5, 5)
# Kronecker sigma min is 1.7736875938827962e-05
# Product sigma min is 1.7736875938827227e-05
# (5, 5)
# Kronecker sigma min is 3.170175579530916e-05
# Product sigma min is 3.1701755795349056e-05
# (5, 5)
# Kronecker sigma min is 4.432419904483252e-05
# Product sigma min is 4.4324199044816454e-05
# (5, 5)
# Kronecker sigma min is 1.4119249099681185e-05
# Product sigma min is 1.4119249099643517e-05
# (5, 5)
# Kronecker sigma min is 3.6293368801372876e-06
# Product sigma min is 3.629336880151561e-06
# (5, 5)
# Kronecker sigma min is 3.5368202922663445e-05
# Product sigma min is 3.5368202922668426e-05
# (5, 5)
# Kronecker sigma min is 3.408620188599558e-05
# Product sigma min is 3.40862018860009e-05
# (5, 5)
# Kronecker sigma min is 2.072596921459938e-05
# Product sigma min is 2.0725969214556837e-05
# (5, 5)
# Kronecker sigma min is 3.77495488479412e-06
# Product sigma min is 3.77495488481469e-06
# (5, 5)
# Kronecker sigma min is 6.871399399994773e-06
# Product sigma min is 6.871399399995538e-06
# (5, 5)
# Kronecker sigma min is 0.0005133539342986258
# Product sigma min is 0.0005133539342986614
# (5, 5)
# Kronecker sigma min is 2.897909737641448e-05
# Product sigma min is 2.8979097376469154e-05
# (5, 5)
# Kronecker sigma min is 8.9540817384299e-06
# Product sigma min is 8.954081738429223e-06
# (5, 5)
# Kronecker sigma min is 3.5175459481486704e-06
# Product sigma min is 3.5175459480827293e-06
# (5, 5)
# Kronecker sigma min is 7.2354738739332355e-06
# Product sigma min is 7.23547387391112e-06
# (5, 5)
# Kronecker sigma min is 0.00041492953651938125
# Product sigma min is 0.0004149295365193945
# (5, 5)
# Kronecker sigma min is 1.6224347416845257e-05
# Product sigma min is 1.6224347416888493e-05
# (5, 5)
# Kronecker sigma min is 3.74884189866017e-05
# Product sigma min is 3.748841898659435e-05
# (5, 5)
# Kronecker sigma min is 4.559243733824861e-06
# Product sigma min is 4.559243733796281e-06
# (5, 5)
# Kronecker sigma min is 0.0003089363619306694
# Product sigma min is 0.0003089363619306573
# (5, 5)
# Kronecker sigma min is 0.0004319431670218945
# Product sigma min is 0.0004319431670218359
# (5, 5)
# Kronecker sigma min is 0.00013759330802355613
# Product sigma min is 0.0001375933080235422
# (5, 5)
# Kronecker sigma min is 3.5368202922667924e-05
# Product sigma min is 3.5368202922668426e-05
# (5, 5)
# Kronecker sigma min is 0.0003446662074331476
# Product sigma min is 0.0003446662074331368
# (5, 5)
# Kronecker sigma min is 0.00033217299605341736
# Product sigma min is 0.0003321729960534219
# (5, 5)
# Kronecker sigma min is 0.0002019763690051677
# Product sigma min is 0.00020197636900513166
# (5, 5)
# Kronecker sigma min is 3.678726301766652e-05
# Product sigma min is 3.678726301771933e-05
# (5, 5)
# Kronecker sigma min is 6.696238358883368e-05
# Product sigma min is 6.696238358881565e-05
# (5, 5)
# Kronecker sigma min is 0.005002678648741735
# Product sigma min is 0.005002678648741761
# (5, 5)
# Kronecker sigma min is 0.0002824038193124914
# Product sigma min is 0.00028240381931255934
# (5, 5)
# Kronecker sigma min is 8.725830375319244e-05
# Product sigma min is 8.725830375319126e-05
# (5, 5)
# Kronecker sigma min is 3.42787905861496e-05
# Product sigma min is 3.4278790586230934e-05
# (5, 5)
# Kronecker sigma min is 7.051032093869111e-05
# Product sigma min is 7.051032093870209e-05
# (5, 5)
# Kronecker sigma min is 0.004043524349168173
# Product sigma min is 0.004043524349168122
# (5, 5)
# Kronecker sigma min is 0.0001581076738471732
# Product sigma min is 0.00015810767384713556
# (5, 5)
# Kronecker sigma min is 0.000365327897010376
# Product sigma min is 0.00036532789701035286
# (5, 5)
# Kronecker sigma min is 4.443022592714387e-05
# Product sigma min is 4.4430225927133406e-05
# (5, 5)
# Kronecker sigma min is 0.0002977382601462449
# Product sigma min is 0.00029773826014625613
# (5, 5)
# Kronecker sigma min is 0.0004162864035409549
# Product sigma min is 0.0004162864035409712
# (5, 5)
# Kronecker sigma min is 0.0001326059253196485
# Product sigma min is 0.00013260592531963788
# (5, 5)
# Kronecker sigma min is 3.408620188597863e-05
# Product sigma min is 3.40862018860009e-05
# (5, 5)
# Kronecker sigma min is 0.00033217299605340836
# Product sigma min is 0.0003321729960534219
# (5, 5)
# Kronecker sigma min is 0.0003201326295631029
# Product sigma min is 0.0003201326295630875
# (5, 5)
# Kronecker sigma min is 0.00019465527567694876
# Product sigma min is 0.00019465527567695006
# (5, 5)
# Kronecker sigma min is 3.545382491717286e-05
# Product sigma min is 3.5453824917174785e-05
# (5, 5)
# Kronecker sigma min is 6.453517954436515e-05
# Product sigma min is 6.45351795443724e-05
# (5, 5)
# Kronecker sigma min is 0.004821345171668478
# Product sigma min is 0.004821345171668464
# (5, 5)
# Kronecker sigma min is 0.00027216744994119766
# Product sigma min is 0.0002721674499412016
# (5, 5)
# Kronecker sigma min is 8.409542787534912e-05
# Product sigma min is 8.409542787527258e-05
# (5, 5)
# Kronecker sigma min is 3.303627777992727e-05
# Product sigma min is 3.303627777993024e-05
# (5, 5)
# Kronecker sigma min is 6.795451382753551e-05
# Product sigma min is 6.79545138275288e-05
# (5, 5)
# Kronecker sigma min is 0.0038969576033609167
# Product sigma min is 0.0038969576033609306
# (5, 5)
# Kronecker sigma min is 0.00015237670124950922
# Product sigma min is 0.00015237670124950873
# (5, 5)
# Kronecker sigma min is 0.0003520857556520628
# Product sigma min is 0.00035208575565205783
# (5, 5)
# Kronecker sigma min is 4.281975123542889e-05
# Product sigma min is 4.281975123543086e-05
# (5, 5)
# Kronecker sigma min is 0.00018103847517025396
# Product sigma min is 0.00018103847517025342
# (5, 5)
# Kronecker sigma min is 0.0002531211665378365
# Product sigma min is 0.00025312116653783656
# (5, 5)
# Kronecker sigma min is 8.06304655189938e-05
# Product sigma min is 8.063046551899322e-05
# (5, 5)
# Kronecker sigma min is 2.072596921455593e-05
# Product sigma min is 2.0725969214556837e-05
# (5, 5)
# Kronecker sigma min is 0.0002019763690051313
# Product sigma min is 0.00020197636900513166
# (5, 5)
# Kronecker sigma min is 0.00019465527567695065
# Product sigma min is 0.00019465527567695006
# (5, 5)
# Kronecker sigma min is 0.00011835930751757802
# Product sigma min is 0.00011835930751758131
# (5, 5)
# Kronecker sigma min is 2.1557546547111924e-05
# Product sigma min is 2.1557546547109986e-05
# (5, 5)
# Kronecker sigma min is 3.924033979983795e-05
# Product sigma min is 3.924033979983819e-05
# (5, 5)
# Kronecker sigma min is 0.002931598302883751
# Product sigma min is 0.002931598302883741
# (5, 5)
# Kronecker sigma min is 0.00016549025343309218
# Product sigma min is 0.0001654902534330907
# (5, 5)
# Kronecker sigma min is 5.113386510639738e-05
# Product sigma min is 5.113386510638818e-05
# (5, 5)
# Kronecker sigma min is 2.008756735409637e-05
# Product sigma min is 2.0087567354096737e-05
# (5, 5)
# Kronecker sigma min is 4.131945138064694e-05
# Product sigma min is 4.131945138064719e-05
# (5, 5)
# Kronecker sigma min is 0.002369528397086188
# Product sigma min is 0.0023695283970861856
# (5, 5)
# Kronecker sigma min is 9.265200123132687e-05
# Product sigma min is 9.265200123132775e-05
# (5, 5)
# Kronecker sigma min is 0.00021408423727976576
# Product sigma min is 0.00021408423727976327
# (5, 5)
# Kronecker sigma min is 2.6036366528856378e-05
# Product sigma min is 2.603636652885659e-05
# (5, 5)
# Kronecker sigma min is 3.2973708930489824e-05
# Product sigma min is 3.297370893050243e-05
# (5, 5)
# Kronecker sigma min is 4.610259593558404e-05
# Product sigma min is 4.61025959355807e-05
# (5, 5)
# Kronecker sigma min is 1.468574842145747e-05
# Product sigma min is 1.468574842145514e-05
# (5, 5)
# Kronecker sigma min is 3.774954884822012e-06
# Product sigma min is 3.77495488481469e-06
# (5, 5)
# Kronecker sigma min is 3.6787263017778386e-05
# Product sigma min is 3.678726301771933e-05
# (5, 5)
# Kronecker sigma min is 3.545382491718209e-05
# Product sigma min is 3.5453824917174785e-05
# (5, 5)
# Kronecker sigma min is 2.155754654711224e-05
# Product sigma min is 2.1557546547109986e-05
# (5, 5)
# Kronecker sigma min is 3.926415445295339e-06
# Product sigma min is 3.926415445289608e-06
# (5, 5)
# Kronecker sigma min is 7.147097000669465e-06
# Product sigma min is 7.14709700066274e-06
# (5, 5)
# Kronecker sigma min is 0.0005339509684310772
# Product sigma min is 0.0005339509684310829
# (5, 5)
# Kronecker sigma min is 3.0141810697445473e-05
# Product sigma min is 3.0141810697455698e-05
# (5, 5)
# Kronecker sigma min is 9.31334172431599e-06
# Product sigma min is 9.313341724315729e-06
# (5, 5)
# Kronecker sigma min is 3.6586786230550727e-06
# Product sigma min is 3.6586786230548283e-06
# (5, 5)
# Kronecker sigma min is 7.525779046198961e-06
# Product sigma min is 7.52577904620671e-06
# (5, 5)
# Kronecker sigma min is 0.0004315775394959515
# Product sigma min is 0.00043157753949596796
# (5, 5)
# Kronecker sigma min is 1.6875308508675966e-05
# Product sigma min is 1.6875308508632073e-05
# (5, 5)
# Kronecker sigma min is 3.8992547413148755e-05
# Product sigma min is 3.8992547413100535e-05
# (5, 5)
# Kronecker sigma min is 4.74217190970402e-06
# Product sigma min is 4.742171909717102e-06
# (5, 5)
# Kronecker sigma min is 6.002072360443064e-05
# Product sigma min is 6.002072360443702e-05
# (5, 5)
# Kronecker sigma min is 8.391871153859996e-05
# Product sigma min is 8.391871153859815e-05
# (5, 5)
# Kronecker sigma min is 2.6731880504742924e-05
# Product sigma min is 2.6731880504745676e-05
# (5, 5)
# Kronecker sigma min is 6.871399399990169e-06
# Product sigma min is 6.871399399995538e-06
# (5, 5)
# Kronecker sigma min is 6.696238358884324e-05
# Product sigma min is 6.696238358881565e-05
# (5, 5)
# Kronecker sigma min is 6.45351795443703e-05
# Product sigma min is 6.45351795443724e-05
# (5, 5)
# Kronecker sigma min is 3.9240339799836425e-05
# Product sigma min is 3.924033979983819e-05
# (5, 5)
# Kronecker sigma min is 7.1470970006649275e-06
# Product sigma min is 7.14709700066274e-06
# (5, 5)
# Kronecker sigma min is 1.3009574826855947e-05
# Product sigma min is 1.3009574826872313e-05
# (5, 5)
# Kronecker sigma min is 0.0009719295928179878
# Product sigma min is 0.0009719295928180313
# (5, 5)
# Kronecker sigma min is 5.4865932510746054e-05
# Product sigma min is 5.486593251072546e-05
# (5, 5)
# Kronecker sigma min is 1.6952703459753098e-05
# Product sigma min is 1.6952703459807844e-05
# (5, 5)
# Kronecker sigma min is 6.659746371106744e-06
# Product sigma min is 6.659746371106517e-06
# (5, 5)
# Kronecker sigma min is 1.3698874609237437e-05
# Product sigma min is 1.3698874609237171e-05
# (5, 5)
# Kronecker sigma min is 0.0007855833344852679
# Product sigma min is 0.0007855833344852601
# (5, 5)
# Kronecker sigma min is 3.071744916142534e-05
# Product sigma min is 3.071744916142124e-05
# (5, 5)
# Kronecker sigma min is 7.097657457483206e-05
# Product sigma min is 7.097657457483211e-05
# (5, 5)
# Kronecker sigma min is 8.63198586721304e-06
# Product sigma min is 8.631985867217956e-06
# (5, 5)
# Kronecker sigma min is 0.0044840756312040835
# Product sigma min is 0.004484075631204071
# (5, 5)
# Kronecker sigma min is 0.006269465391524483
# Product sigma min is 0.00626946539152444
# (5, 5)
# Kronecker sigma min is 0.0019971064450600854
# Product sigma min is 0.001997106445060054
# (5, 5)
# Kronecker sigma min is 0.0005133539342986326
# Product sigma min is 0.0005133539342986614
# (5, 5)
# Kronecker sigma min is 0.0050026786487417695
# Product sigma min is 0.005002678648741761
# (5, 5)
# Kronecker sigma min is 0.004821345171668455
# Product sigma min is 0.004821345171668464
# (5, 5)
# Kronecker sigma min is 0.0029315983028837455
# Product sigma min is 0.002931598302883741
# (5, 5)
# Kronecker sigma min is 0.000533950968431113
# Product sigma min is 0.0005339509684310829
# (5, 5)
# Kronecker sigma min is 0.0009719295928180098
# Product sigma min is 0.0009719295928180313
# (5, 5)
# Kronecker sigma min is 0.07261168377648913
# Product sigma min is 0.072611683776489
# (5, 5)
# Kronecker sigma min is 0.0040989674262514875
# Product sigma min is 0.00409896742625149
# (5, 5)
# Kronecker sigma min is 0.0012665159615227106
# Product sigma min is 0.001266515961522559
# (5, 5)
# Kronecker sigma min is 0.0004975415926253657
# Product sigma min is 0.0004975415926253658
# (5, 5)
# Kronecker sigma min is 0.0010234263454574517
# Product sigma min is 0.0010234263454574485
# (5, 5)
# Kronecker sigma min is 0.05868998030848437
# Product sigma min is 0.05868998030848437
# I should be printed
# (5, 5)
# Kronecker sigma min is 0.0022948634565828157
# Product sigma min is 0.0022948634565827957
# (5, 5)
# Kronecker sigma min is 0.0053025739998545625
# Product sigma min is 0.005302573999854536
# (5, 5)
# Kronecker sigma min is 0.00064488521883178
# Product sigma min is 0.0006448852188317939
# (5, 5)
# Kronecker sigma min is 0.00025312840844911213
# Product sigma min is 0.0002531284084491218
# (5, 5)
# Kronecker sigma min is 0.00035391459174770724
# Product sigma min is 0.00035391459174770724
# I should be printed
# (5, 5)
# Kronecker sigma min is 0.0001127377005917709
# Product sigma min is 0.00011273770059176962
# (5, 5)
# Kronecker sigma min is 2.897909737643913e-05
# Product sigma min is 2.8979097376469154e-05
# (5, 5)
# Kronecker sigma min is 0.00028240381931254806
# Product sigma min is 0.00028240381931255934
# (5, 5)
# Kronecker sigma min is 0.00027216744994123414
# Product sigma min is 0.0002721674499412016
# (5, 5)
# Kronecker sigma min is 0.00016549025343306394
# Product sigma min is 0.0001654902534330907
# (5, 5)
# Kronecker sigma min is 3.0141810697460655e-05
# Product sigma min is 3.0141810697455698e-05
# (5, 5)
# Kronecker sigma min is 5.486593251076806e-05
# Product sigma min is 5.486593251072546e-05
# (5, 5)
# Kronecker sigma min is 0.004098967426251492
# Product sigma min is 0.00409896742625149
# (5, 5)
# Kronecker sigma min is 0.00023138884939216185
# Product sigma min is 0.00023138884939218207
# (5, 5)
# Kronecker sigma min is 7.149548669173094e-05
# Product sigma min is 7.149548669176413e-05
# (5, 5)
# Kronecker sigma min is 2.8086482440684585e-05
# Product sigma min is 2.808648244068132e-05
# (5, 5)
# Kronecker sigma min is 5.777295105991842e-05
# Product sigma min is 5.777295105992275e-05
# (5, 5)
# Kronecker sigma min is 0.0033130800033825346
# Product sigma min is 0.0033130800033824947
# (5, 5)
# Kronecker sigma min is 0.00012954623921383054
# Product sigma min is 0.00012954623921382667
# (5, 5)
# Kronecker sigma min is 0.00029933306831990446
# Product sigma min is 0.0002993330683199146
# (5, 5)
# Kronecker sigma min is 3.640410700017077e-05
# Product sigma min is 3.6404107000180654e-05
# (5, 5)
# Kronecker sigma min is 7.821266584415496e-05
# Product sigma min is 7.821266584418689e-05
# (5, 5)
# Kronecker sigma min is 0.00010935399891036143
# Product sigma min is 0.00010935399891043436
# (5, 5)
# Kronecker sigma min is 3.4834162465048134e-05
# Product sigma min is 3.4834162465009794e-05
# (5, 5)
# Kronecker sigma min is 8.954081738409853e-06
# Product sigma min is 8.954081738429223e-06
# (5, 5)
# Kronecker sigma min is 8.725830375318169e-05
# Product sigma min is 8.725830375319126e-05
# (5, 5)
# Kronecker sigma min is 8.40954278752317e-05
# Product sigma min is 8.409542787527258e-05
# (5, 5)
# Kronecker sigma min is 5.11338651064001e-05
# Product sigma min is 5.113386510638818e-05
# (5, 5)
# Kronecker sigma min is 9.313341724353915e-06
# Product sigma min is 9.313341724315729e-06
# (5, 5)
# Kronecker sigma min is 1.6952703459749317e-05
# Product sigma min is 1.6952703459807844e-05
# (5, 5)
# Kronecker sigma min is 0.0012665159615225239
# Product sigma min is 0.001266515961522559
# (5, 5)
# Kronecker sigma min is 7.149548669181004e-05
# Product sigma min is 7.149548669176413e-05
# (5, 5)
# Kronecker sigma min is 2.209097210482853e-05
# Product sigma min is 2.209097210483353e-05
# (5, 5)
# Kronecker sigma min is 8.67827787215081e-06
# Product sigma min is 8.678277872209533e-06
# (5, 5)
# Kronecker sigma min is 1.785092611201535e-05
# Product sigma min is 1.7850926112035045e-05
# (5, 5)
# Kronecker sigma min is 0.0010236892050450668
# Product sigma min is 0.001023689205045099
# (5, 5)
# Kronecker sigma min is 4.002773446515579e-05
# Product sigma min is 4.002773446520786e-05
# (5, 5)
# Kronecker sigma min is 9.248917334902374e-05
# Product sigma min is 9.24891733490527e-05
# (5, 5)
# Kronecker sigma min is 1.1248292017512659e-05
# Product sigma min is 1.124829201750165e-05
# (5, 5)
# Kronecker sigma min is 3.0725277461817175e-05
# Product sigma min is 3.0725277461810466e-05
# (5, 5)
# Kronecker sigma min is 4.29589238752463e-05
# Product sigma min is 4.2958923875260546e-05
# (5, 5)
# Kronecker sigma min is 1.3684347609621464e-05
# Product sigma min is 1.3684347609623873e-05
# (5, 5)
# Kronecker sigma min is 3.517545948081626e-06
# Product sigma min is 3.5175459480827293e-06
# (5, 5)
# Kronecker sigma min is 3.427879058623222e-05
# Product sigma min is 3.4278790586230934e-05
# (5, 5)
# Kronecker sigma min is 3.303627777992045e-05
# Product sigma min is 3.303627777993024e-05
# (5, 5)
# Kronecker sigma min is 2.008756735409771e-05
# Product sigma min is 2.0087567354096737e-05
# (5, 5)
# Kronecker sigma min is 3.6586786230445834e-06
# Product sigma min is 3.6586786230548283e-06
# (5, 5)
# Kronecker sigma min is 6.659746371120626e-06
# Product sigma min is 6.659746371106517e-06
# (5, 5)
# Kronecker sigma min is 0.0004975415926253658
# Product sigma min is 0.0004975415926253658
# I should be printed
# (5, 5)
# Kronecker sigma min is 2.808648244068536e-05
# Product sigma min is 2.808648244068132e-05
# (5, 5)
# Kronecker sigma min is 8.678277872232897e-06
# Product sigma min is 8.678277872209533e-06
# (5, 5)
# Kronecker sigma min is 3.4091984033014875e-06
# Product sigma min is 3.409198403306261e-06
# (5, 5)
# Kronecker sigma min is 7.01260661328597e-06
# Product sigma min is 7.0126066132972685e-06
# (5, 5)
# Kronecker sigma min is 0.0004021488657902515
# Product sigma min is 0.00040214886579024073
# (5, 5)
# Kronecker sigma min is 1.5724604631935625e-05
# Product sigma min is 1.572460463195673e-05
# (5, 5)
# Kronecker sigma min is 3.6333699698007724e-05
# Product sigma min is 3.63336996980054e-05
# (5, 5)
# Kronecker sigma min is 4.418809785835527e-06
# Product sigma min is 4.418809785843569e-06
# (5, 5)
# Kronecker sigma min is 6.320086379106746e-05
# Product sigma min is 6.320086379106803e-05
# (5, 5)
# Kronecker sigma min is 8.836506358081294e-05
# Product sigma min is 8.836506358081948e-05
# (5, 5)
# Kronecker sigma min is 2.8148243426622395e-05
# Product sigma min is 2.8148243426619467e-05
# (5, 5)
# Kronecker sigma min is 7.235473873908284e-06
# Product sigma min is 7.23547387391112e-06
# (5, 5)
# Kronecker sigma min is 7.051032093870165e-05
# Product sigma min is 7.051032093870209e-05
# (5, 5)
# Kronecker sigma min is 6.795451382752654e-05
# Product sigma min is 6.79545138275288e-05
# (5, 5)
# Kronecker sigma min is 4.131945138064386e-05
# Product sigma min is 4.131945138064719e-05
# (5, 5)
# Kronecker sigma min is 7.525779046208748e-06
# Product sigma min is 7.52577904620671e-06
# (5, 5)
# Kronecker sigma min is 1.3698874609236332e-05
# Product sigma min is 1.3698874609237171e-05
# (5, 5)
# Kronecker sigma min is 0.0010234263454574433
# Product sigma min is 0.0010234263454574485
# (5, 5)
# Kronecker sigma min is 5.7772951059922976e-05
# Product sigma min is 5.777295105992275e-05
# (5, 5)
# Kronecker sigma min is 1.785092611203618e-05
# Product sigma min is 1.7850926112035045e-05
# (5, 5)
# Kronecker sigma min is 7.012606613290455e-06
# Product sigma min is 7.0126066132972685e-06
# (5, 5)
# Kronecker sigma min is 1.4424696276159722e-05
# Product sigma min is 1.4424696276159456e-05
# (5, 5)
# Kronecker sigma min is 0.0008272067102447541
# Product sigma min is 0.0008272067102447532
# (5, 5)
# Kronecker sigma min is 3.2344983596912815e-05
# Product sigma min is 3.234498359690761e-05
# (5, 5)
# Kronecker sigma min is 7.473719996485967e-05
# Product sigma min is 7.473719996486239e-05
# (5, 5)
# Kronecker sigma min is 9.089343318084474e-06
# Product sigma min is 9.0893433180825e-06
# (5, 5)
# Kronecker sigma min is 0.003624352126404396
# Product sigma min is 0.0036243521264043978
# (5, 5)
# Kronecker sigma min is 0.005067432419084507
# Product sigma min is 0.005067432419084517
# (5, 5)
# Kronecker sigma min is 0.001614204930095249
# Product sigma min is 0.0016142049300951946
# (5, 5)
# Kronecker sigma min is 0.0004149295365194133
# Product sigma min is 0.0004149295365193945
# (5, 5)
# Kronecker sigma min is 0.004043524349168141
# Product sigma min is 0.004043524349168122
# (5, 5)
# Kronecker sigma min is 0.0038969576033609436
# Product sigma min is 0.0038969576033609306
# (5, 5)
# Kronecker sigma min is 0.002369528397086188
# Product sigma min is 0.0023695283970861856
# (5, 5)
# Kronecker sigma min is 0.0004315775394959565
# Product sigma min is 0.00043157753949596796
# (5, 5)
# Kronecker sigma min is 0.0007855833344852436
# Product sigma min is 0.0007855833344852601
# (5, 5)
# Kronecker sigma min is 0.05868998030848438
# Product sigma min is 0.05868998030848437
# (5, 5)
# Kronecker sigma min is 0.0033130800033824696
# Product sigma min is 0.0033130800033824947
# (5, 5)
# Kronecker sigma min is 0.0010236892050451574
# Product sigma min is 0.001023689205045099
# (5, 5)
# Kronecker sigma min is 0.00040214886579024794
# Product sigma min is 0.00040214886579024073
# (5, 5)
# Kronecker sigma min is 0.0008272067102447506
# Product sigma min is 0.0008272067102447532
# (5, 5)
# Kronecker sigma min is 0.04743745922781625
# Product sigma min is 0.04743745922781625
# I should be printed
# (5, 5)
# Kronecker sigma min is 0.0018548735420058592
# Product sigma min is 0.0018548735420058475
# (5, 5)
# Kronecker sigma min is 0.0042859213207848985
# Product sigma min is 0.004285921320784882
# (5, 5)
# Kronecker sigma min is 0.0005212425718011731
# Product sigma min is 0.0005212425718011728
# (5, 5)
# Kronecker sigma min is 0.00014171743123709058
# Product sigma min is 0.00014171743123708662
# (5, 5)
# Kronecker sigma min is 0.00019814396624663329
# Product sigma min is 0.00019814396624663524
# (5, 5)
# Kronecker sigma min is 6.31177568307442e-05
# Product sigma min is 6.311775683073e-05
# (5, 5)
# Kronecker sigma min is 1.6224347416891038e-05
# Product sigma min is 1.6224347416888493e-05
# (5, 5)
# Kronecker sigma min is 0.00015810767384712732
# Product sigma min is 0.00015810767384713556
# (5, 5)
# Kronecker sigma min is 0.00015237670124950862
# Product sigma min is 0.00015237670124950873
# (5, 5)
# Kronecker sigma min is 9.265200123133142e-05
# Product sigma min is 9.265200123132775e-05
# (5, 5)
# Kronecker sigma min is 1.6875308508626476e-05
# Product sigma min is 1.6875308508632073e-05
# (5, 5)
# Kronecker sigma min is 3.071744916142532e-05
# Product sigma min is 3.071744916142124e-05
# (5, 5)
# Kronecker sigma min is 0.002294863456582818
# Product sigma min is 0.0022948634565827957
# (5, 5)
# Kronecker sigma min is 0.00012954623921380948
# Product sigma min is 0.00012954623921382667
# (5, 5)
# Kronecker sigma min is 4.0027734465163026e-05
# Product sigma min is 4.002773446520786e-05
# (5, 5)
# Kronecker sigma min is 1.57246046319683e-05
# Product sigma min is 1.572460463195673e-05
# (5, 5)
# Kronecker sigma min is 3.234498359690413e-05
# Product sigma min is 3.234498359690761e-05
# (5, 5)
# Kronecker sigma min is 0.001854873542005849
# Product sigma min is 0.0018548735420058475
# (5, 5)
# Kronecker sigma min is 7.25282490428285e-05
# Product sigma min is 7.252824904281244e-05
# (5, 5)
# Kronecker sigma min is 0.00016758574743356487
# Product sigma min is 0.00016758574743356043
# (5, 5)
# Kronecker sigma min is 2.0381341478645413e-05
# Product sigma min is 2.0381341478637752e-05
# (5, 5)
# Kronecker sigma min is 0.00032745615607254346
# Product sigma min is 0.0003274561560725417
# (5, 5)
# Kronecker sigma min is 0.0004578368445554456
# Product sigma min is 0.0004578368445554424
# (5, 5)
# Kronecker sigma min is 0.00014584160784805576
# Product sigma min is 0.00014584160784805055
# (5, 5)
# Kronecker sigma min is 3.7488418986593275e-05
# Product sigma min is 3.748841898659435e-05
# (5, 5)
# Kronecker sigma min is 0.0003653278970103546
# Product sigma min is 0.00036532789701035286
# (5, 5)
# Kronecker sigma min is 0.0003520857556520576
# Product sigma min is 0.00035208575565205783
# (5, 5)
# Kronecker sigma min is 0.00021408423727976416
# Product sigma min is 0.00021408423727976327
# (5, 5)
# Kronecker sigma min is 3.899254741310098e-05
# Product sigma min is 3.8992547413100535e-05
# (5, 5)
# Kronecker sigma min is 7.097657457482871e-05
# Product sigma min is 7.097657457483211e-05
# (5, 5)
# Kronecker sigma min is 0.005302573999854563
# Product sigma min is 0.005302573999854536
# (5, 5)
# Kronecker sigma min is 0.00029933306831990273
# Product sigma min is 0.0002993330683199146
# (5, 5)
# Kronecker sigma min is 9.24891733490505e-05
# Product sigma min is 9.24891733490527e-05
# (5, 5)
# Kronecker sigma min is 3.633369969800603e-05
# Product sigma min is 3.63336996980054e-05
# (5, 5)
# Kronecker sigma min is 7.473719996486305e-05
# Product sigma min is 7.473719996486239e-05
# (5, 5)
# Kronecker sigma min is 0.004285921320784888
# Product sigma min is 0.004285921320784882
# (5, 5)
# Kronecker sigma min is 0.00016758574743356517
# Product sigma min is 0.00016758574743356043
# (5, 5)
# Kronecker sigma min is 0.000387228191959891
# Product sigma min is 0.000387228191959893
# (5, 5)
# Kronecker sigma min is 4.709368267500653e-05
# Product sigma min is 4.7093682675007634e-05
# (5, 5)
# Kronecker sigma min is 3.982436357746725e-05
# Product sigma min is 3.98243635774724e-05
# (5, 5)
# Kronecker sigma min is 5.5680922830780226e-05
# Product sigma min is 5.5680922830778796e-05
# (5, 5)
# Kronecker sigma min is 1.7736875938827234e-05
# Product sigma min is 1.7736875938827227e-05
# (5, 5)
# Kronecker sigma min is 4.559243733795347e-06
# Product sigma min is 4.559243733796281e-06
# (5, 5)
# Kronecker sigma min is 4.443022592713605e-05
# Product sigma min is 4.4430225927133406e-05
# (5, 5)
# Kronecker sigma min is 4.281975123543409e-05
# Product sigma min is 4.281975123543086e-05
# (5, 5)
# Kronecker sigma min is 2.6036366528856158e-05
# Product sigma min is 2.603636652885659e-05
# (5, 5)
# Kronecker sigma min is 4.742171909717977e-06
# Product sigma min is 4.742171909717102e-06
# (5, 5)
# Kronecker sigma min is 8.631985867216091e-06
# Product sigma min is 8.631985867217956e-06
# (5, 5)
# Kronecker sigma min is 0.0006448852188317703
# Product sigma min is 0.0006448852188317939
# (5, 5)
# Kronecker sigma min is 3.640410700018271e-05
# Product sigma min is 3.6404107000180654e-05
# (5, 5)
# Kronecker sigma min is 1.1248292017502301e-05
# Product sigma min is 1.124829201750165e-05
# (5, 5)
# Kronecker sigma min is 4.418809785838528e-06
# Product sigma min is 4.418809785843569e-06
# (5, 5)
# Kronecker sigma min is 9.089343318081948e-06
# Product sigma min is 9.0893433180825e-06
# (5, 5)
# Kronecker sigma min is 0.0005212425718011565
# Product sigma min is 0.0005212425718011728
# (5, 5)
# Kronecker sigma min is 2.038134147863814e-05
# Product sigma min is 2.0381341478637752e-05
# (5, 5)
# Kronecker sigma min is 4.7093682675006204e-05
# Product sigma min is 4.7093682675007634e-05
# (5, 5)
# Kronecker sigma min is 5.7274108495777394e-06
# Product sigma min is 5.727410849579938e-06
# Stationary distribution before normalization is [-0.52381946+0.j -0.32709755+0.j -0.50287931+0.j -0.37643409+0.j
#  -0.47331823+0.j]
# Stationary distribution is [0.23771631-0.j 0.14844127-0.j 0.22821339-0.j 0.17083085-0.j
#  0.21479818-0.j]
# [0.23771631 0.14844127 0.22821339 0.17083085 0.21479818]
# The transition matrix is
# [[0.67515924 0.05732484 0.17197452 0.01910828 0.07643312]
#  [0.04265403 0.48815166 0.19905213 0.09952607 0.17061611]
#  [0.17004049 0.06072874 0.4534413  0.15789474 0.15789474]
#  [0.10650888 0.0887574  0.10650888 0.62721893 0.07100592]
#  [0.06465517 0.15517241 0.16810345 0.0387931  0.57327586]]
# The stationary distribution is
# [0.23771631 0.14844127 0.22821339 0.17083085 0.21479818]
# The transition stationary distribution is
# [[0.16049636 0.01362705 0.04088115 0.00454235 0.0181694 ]
#  [0.00633162 0.07246185 0.02954755 0.01477378 0.02532647]
#  [0.03880552 0.01385911 0.10348138 0.03603369 0.03603369]
#  [0.018195   0.0151625  0.018195   0.10714834 0.01213   ]
#  [0.01388781 0.03333075 0.03610831 0.00833269 0.12313861]]

# %%
# check the spectral gap between the original matrix and the iterated one
second_eig = utils.compute_second_eigenvalue(real_transition_matrix)
original_spectral_gap = 1 - second_eig
print(f"Original spectral gap is {original_spectral_gap}")

iterated_mat = real_transition_matrix
for i in range(1000):
    iterated_mat = np.matmul(iterated_mat, real_transition_matrix)
    second_eig = utils.compute_second_eigenvalue(iterated_mat)
    spectral_gap = 1 - second_eig
    print(f"Spectra gap is {spectral_gap}")
# Out:
# Original spectral gap is 0.4109789385883069
# Spectra gap is 0.6530541892134428
# Spectra gap is 0.7956416102781615
# Spectra gap is 0.8796286043776586
# Spectra gap is 0.9290987127869215
# Spectra gap is 0.958237648550297
# Spectra gap is 0.975401095422048
# Spectra gap is 0.9855107271159299
# Spectra gap is 0.9914655131067415
# Spectra gap is 0.9949730074715287
# Spectra gap is 0.9970389955251714
# Spectra gap is 0.9982559060013915
# Spectra gap is 0.998972691901738
# Spectra gap is 0.9993948938935651
# Spectra gap is 0.9996435797589208
# Spectra gap is 0.9997900609712908
# Spectra gap is 0.999876341490478
# Spectra gap is 0.9999271625334688
# Spectra gap is 0.9999570971981531
# Spectra gap is 0.9999747293461188
# Spectra gap is 0.9999851150526284
# Spectra gap is 0.9999912324525001
# Spectra gap is 0.9999948357298651
# Spectra gap is 0.9999969581361239
# Spectra gap is 0.9999982082781109
# Spectra gap is 0.9999989446380715
# Spectra gap is 0.9999993783695966
# Spectra gap is 0.9999996338466002
# Spectra gap is 0.9999997843279357
# Spectra gap is 0.9999998729646116
# Spectra gap is 0.9999999251734806
# Spectra gap is 0.9999999559256044
# Spectra gap is 0.9999999740392526
# Spectra gap is 0.9999999847085731
# Spectra gap is 0.9999999909930276
# Spectra gap is 0.9999999946947035
# Spectra gap is 0.9999999968750687
# Spectra gap is 0.9999999981593496
# Spectra gap is 0.9999999989158179
# Spectra gap is 0.999999999361394
# Spectra gap is 0.9999999996238474
# Spectra gap is 0.9999999997784382
# Spectra gap is 0.9999999998694954
# Spectra gap is 0.99999999992313
# Spectra gap is 0.999999999954722
# Spectra gap is 0.9999999999733303
# Spectra gap is 0.9999999999842911
# Spectra gap is 0.9999999999907468
# Spectra gap is 0.9999999999945498
# Spectra gap is 0.9999999999967898
# Spectra gap is 0.9999999999981092
# Spectra gap is 0.9999999999988862
# Spectra gap is 0.999999999999344
# Spectra gap is 0.9999999999996136
# Spectra gap is 0.9999999999997724
# Spectra gap is 0.9999999999998657
# Spectra gap is 0.999999999999921
# Spectra gap is 0.9999999999999534
# Spectra gap is 0.9999999999999727
# Spectra gap is 0.9999999999999838
# Spectra gap is 0.9999999999999902
# Spectra gap is 0.9999999999999943
# Spectra gap is 0.9999999999999966
# Spectra gap is 0.9999999999999981
# Spectra gap is 0.9999999999999989
# Spectra gap is 0.9999999999999993
# Spectra gap is 0.9999999999999999
# Spectra gap is 0.9999999999999998
# Spectra gap is 0.9999999999999998
# Spectra gap is 0.9999999999999999
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 0.9999999999999998
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0
# Spectra gap is 1.0

# %%
# check the spectral gap between the original matrix and the iterated one
original_second_eig = utils.compute_second_eigenvalue(real_transition_matrix)
original_spectral_gap = 1 - original_second_eig
print(f"Original spectral gap is {original_spectral_gap}")

iterated_mat = real_transition_matrix
for i in range(40):
    iterated_mat = np.matmul(iterated_mat, real_transition_matrix)
    second_eig = utils.compute_second_eigenvalue(iterated_mat)
    spectral_gap = 1 - second_eig
    
    # theoretical
    theo_spectral_gap = 1 - original_second_eig**(i+2)
    print(f"Spectra gap is {spectral_gap}, theo is {theo_spectral_gap}")
# Out:
# Original spectral gap is 0.4109789385883069
# Spectra gap is 0.6530541892134428, theo is 0.6530541892134425
# Spectra gap is 0.7956416102781615, theo is 0.7956416102781615
# Spectra gap is 0.8796286043776586, theo is 0.8796286043776582
# Spectra gap is 0.9290987127869215, theo is 0.9290987127869215
# Spectra gap is 0.958237648550297, theo is 0.9582376485502971
# Spectra gap is 0.975401095422048, theo is 0.9754010954220479
# Spectra gap is 0.9855107271159299, theo is 0.9855107271159297
# Spectra gap is 0.9914655131067415, theo is 0.9914655131067412
# Spectra gap is 0.9949730074715287, theo is 0.9949730074715285
# Spectra gap is 0.9970389955251714, theo is 0.9970389955251711
# Spectra gap is 0.9982559060013915, theo is 0.9982559060013915
# Spectra gap is 0.998972691901738, theo is 0.9989726919017379
# Spectra gap is 0.9993948938935651, theo is 0.9993948938935648
# Spectra gap is 0.9996435797589208, theo is 0.9996435797589208
# Spectra gap is 0.9997900609712908, theo is 0.999790060971291
# Spectra gap is 0.999876341490478, theo is 0.9998763414904781
# Spectra gap is 0.9999271625334688, theo is 0.9999271625334688
# Spectra gap is 0.9999570971981531, theo is 0.9999570971981533
# Spectra gap is 0.9999747293461188, theo is 0.9999747293461186
# Spectra gap is 0.9999851150526284, theo is 0.9999851150526282
# Spectra gap is 0.9999912324525001, theo is 0.9999912324525
# Spectra gap is 0.9999948357298651, theo is 0.9999948357298656
# Spectra gap is 0.9999969581361239, theo is 0.999996958136124
# Spectra gap is 0.9999982082781109, theo is 0.9999982082781111
# Spectra gap is 0.9999989446380715, theo is 0.9999989446380713
# Spectra gap is 0.9999993783695966, theo is 0.9999993783695965
# Spectra gap is 0.9999996338466002, theo is 0.9999996338466
# Spectra gap is 0.9999997843279357, theo is 0.9999997843279357
# Spectra gap is 0.9999998729646116, theo is 0.9999998729646118
# Spectra gap is 0.9999999251734806, theo is 0.9999999251734808
# Spectra gap is 0.9999999559256044, theo is 0.9999999559256042
# Spectra gap is 0.9999999740392526, theo is 0.9999999740392527
# Spectra gap is 0.9999999847085731, theo is 0.999999984708573
# Spectra gap is 0.9999999909930276, theo is 0.9999999909930275
# Spectra gap is 0.9999999946947035, theo is 0.9999999946947035
# Spectra gap is 0.9999999968750687, theo is 0.9999999968750686
# Spectra gap is 0.9999999981593496, theo is 0.9999999981593496
# Spectra gap is 0.9999999989158179, theo is 0.9999999989158181
# Spectra gap is 0.999999999361394, theo is 0.999999999361394
# Spectra gap is 0.9999999996238474, theo is 0.9999999996238477

# %%
random_matrix = np.random.random(size=(num_states, num_states)) * 0.1
perturbed_transition_matrix = real_transition_matrix + random_matrix
perturbed_transition_matrix = perturbed_transition_matrix / perturbed_transition_matrix.sum(axis=1)[:, None]
print(f"Real transition matrix is {real_transition_matrix}")
print(f"Perturbed transition matrix is {perturbed_transition_matrix}")

transition_distance = np.absolute(real_transition_matrix.reshape(-1) -
                              perturbed_transition_matrix.reshape(-1))
print(f"Distance vector is {abs(np.sum(transition_distance))}")
# Out:
# Real transition matrix is [[0.54210526 0.01578947 0.12631579 0.18947368 0.12631579]
#  [0.21634615 0.59615385 0.04326923 0.01442308 0.12980769]
#  [0.04663212 0.17098446 0.70466321 0.06217617 0.01554404]
#  [0.17030568 0.11790393 0.03930131 0.6069869  0.06550218]
#  [0.1640625  0.1640625  0.10546875 0.12890625 0.4375    ]]
# Perturbed transition matrix is [[0.447583   0.02457175 0.17705212 0.18838727 0.16240586]
#  [0.20179412 0.52296069 0.08595904 0.02896905 0.16031709]
#  [0.04152947 0.18260469 0.59280221 0.11507306 0.06799057]
#  [0.14236706 0.13747211 0.07743499 0.5421664  0.10055944]
#  [0.1776935  0.16685033 0.15763614 0.12023754 0.37758249]]
# Distance vector is 0.9233257122986802

# %%
belief = np.ones(shape=num_states) * 1/num_states
cumulated_difference = 0
all_prob = 0
distance_vec = np.zeros(shape=num_states)
for first_state in range(num_states):
    for second_state in range(num_states):
        real_prob = belief[first_state] * real_transition_matrix[first_state, second_state]
        all_prob += real_prob
        perturbed_prob = belief[first_state] * perturbed_transition_matrix[first_state, second_state]
        distance = real_prob - perturbed_prob
        distance_vec[second_state] += distance

print(distance_vec)
belief_distance = np.absolute(distance_vec)
print(f"Sum of distances is {np.sum(belief_distance)}")
# Out:
# [ 0.02569691  0.00608693 -0.01437324  0.00142655 -0.01883715]
# Sum of distances is 0.06642078137007809

# %%
belief = np.ones(shape=num_states) * 1/num_states
cumulated_difference = 0
all_prob = 0
final_belief = np.zeros(shape=num_states)
for first_state in range(num_states):
    for second_state in range(num_states):
        for third_state in range(num_states):
            real_prob = belief[first_state] * real_transition_matrix[first_state, second_state] * real_transition_matrix[second_state, third_state]
            final_belief[third_state] += real_prob

print(final_belief)
# Out:
# [0.23866846 0.21445968 0.20583093 0.20053077 0.14051017]

# %%
after_first_belief = np.dot(belief, real_transition_matrix)
after_second_belief = np.dot(after_first_belief, real_transition_matrix)
print(after_second_belief)
# Out:
# [0.23866846 0.21445968 0.20583093 0.20053077 0.14051017]

# %%
real_belief = np.dot(belief, real_transition_matrix)
print(real_belief)
perturbed_belief = np.dot(belief, perturbed_transition_matrix)
print(perturbed_belief)

belief_distance = np.absolute(real_belief.reshape(-1) -
                              perturbed_belief.reshape(-1))
print(f"Distance vector is {np.sum(belief_distance)}")

belief_distance = real_belief.reshape(-1) - perturbed_belief.reshape(-1)
print(f"Distance vector is {belief_distance}")
# Out:
# [0.22789034 0.21297884 0.20380366 0.20039322 0.15493394]
# [0.20219343 0.20689191 0.2181769  0.19896666 0.17377109]
# Distance vector is 0.06642078137007806

# %%
real = real_transition_matrix
perturbed_transition_matrix = switching.generate_transition_matrix_v2(transition_multiplier=20)
perturbed = perturbed_transition_matrix
distance = np.absolute(real_transition_matrix.reshape(-1) -
                          perturbed_transition_matrix.reshape(-1))
print(f"Original distance is {np.sum(distance)}")

for i in range(20):
    real = np.dot(real, real_transition_matrix)
    perturbed = np.dot(perturbed, perturbed_transition_matrix)
    distance = np.absolute(real.reshape(-1) -
                              perturbed.reshape(-1))
    print(f"Distance vector is {np.sum(distance)}")
# Out:
# Original distance is 1.9881915103578964
# Distance vector is 2.2084628286957586
# Distance vector is 2.000540563312738
# Distance vector is 1.7331799133806454
# Distance vector is 1.546154574359751
# Distance vector is 1.4615472078743055
# Distance vector is 1.4324649367456694
# Distance vector is 1.4441218373425508
# Distance vector is 1.4631003663278965
# Distance vector is 1.476927065942491
# Distance vector is 1.4870632075173718
# Distance vector is 1.4945247869754958
# Distance vector is 1.5000323654212233
# Distance vector is 1.5041045438423328
# Distance vector is 1.5071184993776963
# Distance vector is 1.509350530211577
# Distance vector is 1.511003999725247
# Distance vector is 1.5122290419926054
# Distance vector is 1.5131366987081099
# Distance vector is 1.5138091859015383
# Distance vector is 1.5143074118460875
